# %% [markdown]
# # MEDA
# Multivariate EDA

# %%
import logging
import warnings
logger = logging.getLogger(__name__)
logging.basicConfig(filename="logs/explorify.log", encoding="utf-8", level=logging.DEBUG)
warnings.filterwarnings("ignore")

# %%
from explorify.utils.io import IOService
import pandas as pd

# %%
FP = "tests/data/Credit Score Classification Dataset.csv"
df = IOService.read(FP)
df2 = pd.get_dummies(data=df)

# %%
df2.head()
# Out:
#           rating  vote_sum  vote_count                date  review_length  \
# 15304956       1         0           0 2008-09-04 20:09:46             26
# 1563002        5         0           0 2008-10-14 01:23:00             19
# 3868916        5         1           2 2008-11-03 05:40:12              2
# 15304959       1         0           0 2008-12-12 06:59:22              8
# 16466431       5         4           4 2008-12-20 05:11:03             31
#
#           year  id_10000147534  id_1000055614  id_10000710852  id_10001149670  \
# 15304956  2008           False          False           False           False
# 1563002   2008           False          False           False           False
# 3868916   2008           False          False           False           False
# 15304959  2008           False          False           False           False
# 16466431  2008           False          False           False           False
#
#           ...  ymd_2023-08-06  ymd_2023-08-07  ymd_2023-08-08  ymd_2023-08-09  \
# 15304956  ...           False           False           False           False
# 1563002   ...           False           False           False           False
# 3868916   ...           False           False           False           False
# 15304959  ...           False           False           False           False
# 16466431  ...           False           False           False           False
#
#           ymd_2023-08-10  ymd_2023-08-11  ymd_2023-08-13  ymd_2023-08-15  \
# 15304956           False           False           False           False
# 1563002            False           False           False           False
# 3868916            False           False           False           False
# 15304959           False           False           False           False
# 16466431           False           False           False           False
#
#           ymd_2023-08-16  ymd_2023-08-17
# 15304956           False           False
# 1563002            False           False
# 3868916            False           False
# 15304959           False           False
# 16466431           False           False
#
# [5 rows x 66565 columns]
