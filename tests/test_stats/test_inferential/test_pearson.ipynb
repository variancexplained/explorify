# %% [markdown]
# # Pearson Correlation

# %%
import pandas as pd
import numpy as np
from explorify.eda.stats.inferential.correlation import PearsonCorrelationTest
from studioai.visual.container import AnalysisContainer

# %% [markdown]
# ## Dependencies

# %%
container = AnalysisContainer()
container.init_resources()
container.wire(modules=["explorify.eda.stats.inferential.correlation"])

# %% [markdown]
# ## Data

# %%
FP = "data/Credit Score Classification Dataset.csv"
df = pd.read_csv(FP, index_col=None)
income = df['Income'].values
age = df['Age'].values

# %%
test = PearsonCorrelationTest(data=df, a="Income", b="Age")
test.run()
test.result.plot()
