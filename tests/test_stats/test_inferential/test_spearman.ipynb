# %% [markdown]
# # Spearman Correlation

# %%
import pandas as pd
import numpy as np
from explorify.eda.stats.inferential.correlation import SpearmanCorrelationTest
from studioai.visual.container import AnalyzerContainer

# %% [markdown]
# ## Dependencies

# %%
container = AnalyzerContainer()
container.init_resources()
container.wire(modules=["explorify.eda.stats.inferential.correlation"])

# %% [markdown]
# ## Data

# %%
FP = "data/Credit Score Classification Dataset.csv"
df = pd.read_csv(FP, index_col=None)
income = df['Income'].values
age = df['Age'].values

# %%
test = SpearmanCorrelationTest(data=df, a_name="Income", b_name="Age")
test.run()
test.result.plot()
