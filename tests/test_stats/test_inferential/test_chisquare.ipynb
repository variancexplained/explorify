# %% [markdown]
# # ChiSquare Test

# %%
import pandas as pd
from explorify.eda.stats.inferential.independence import ChiSquareIndependenceTest
from studioai.visual.container import AnalysisContainer

# %% [markdown]
# ## Dependencies

# %%
container = AnalysisContainer()
container.init_resources()
container.wire(modules=["explorify.eda.stats.inferential.independence"])

# %% [markdown]
# ## Data

# %%
FP = "data/Credit Score Classification Dataset.csv"
df = pd.read_csv(FP, index_col=None)

# %%
test = ChiSquareIndependenceTest(data=df, a="Gender", b="Credit Rating")
test.run()
test.result.plot()
